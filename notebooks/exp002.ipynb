# %%
import os
from typing import *

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


# %matplotlib inline
sns.set_style("whitegrid")

# %%
from dataclasses import dataclass, field
from glob import glob

import torch


@dataclass
class InputPath:
    _prefix: str = "../input"
    train_images: str = f"{_prefix}/christ-train-imgs.npz"
    train_labels: str = f"{_prefix}/christ-train-labels.npz"
    test_images: str = f"{_prefix}/christ-test-imgs.npz"
    images_prefix: str = f"{_prefix}/data/train/0"
        
        
@dataclass
class OutputPath:
    _prefix: str = "../output"
    model: str = f"{_prefix}/model"
    submission: str = f"{_prefix}/submission"

        
@dataclass
class Basic:
    run_name: str = "exp002"
    is_debug: bool = False
    seed: int = 42
    device: str = "cuda" if torch.cuda.is_available() else "cpu"
        
        
@dataclass
class Kfold:
    number: int = 5
    method: str = "skf"
    shuffle: bool = True
    columns: List[str] = field(default_factory=lambda: ["target"])
        
        
@dataclass
class Adam:
    name: str = "Adam"
    lr: float = 1e-5
    weight_decay: float = 0
    amsgrad: bool = False
        
        
@dataclass
class ReduceLROnPlateau:
    name: str = "ReduceLROnPlateau"
    mode: str = "min"
    factor: float = 0.1
    patience: int = 5
    verbose: bool = True
    eps: float = 1e-8

        
@dataclass
class Params:
    model_name: str = "resnet34"
    batch_size: int = 64
    test_batch_size: int = 256
    epochs: int = 3 if Basic.is_debug else 100
    image_size: int = 224
    num_workers: int = 0
    target_size: int = 13
    # Union[Adam]
    optimizer: Adam = Adam()
    # Union[CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau]
    scheduler: ReduceLROnPlateau = ReduceLROnPlateau()
    pretrained: bool = True
    num_aug: int = 5
    num_tta: int = 2
    early_stopping_rounds: int = 10


# @dataclass
# class DinoParams:
#     arch: str = "vit_small"
#     embed_dim: int = 384
#     patch_size: int = 16
#     checkpoint: str = f"../output/model/dino/{Basic.run_name}/checkpoint1540.pth"
        

@dataclass
class ModelConfig:
    basic: Basic = Basic()
    kfold: Kfold = Kfold()
    params: Params = Params()
#     dino_params: DinoParams = DinoParams()

# %%
# for x in os.listdir(OutputPath.model):
#     if x.startswith(f"{Basic.run_name}_"):
#         os.remove(f"{OutputPath.model}/{x}")

# %%
past_sessions = [x.split("_")[0] for x in os.listdir(OutputPath.model) if x.endswith("_0.pth")]
assert Basic.run_name not in past_sessions

# %%
import math
import os
import random
import time

import joblib
import numpy as np
import torch
from sklearn import metrics


class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


class Jbl:
    @staticmethod
    def load(filepath: str) -> Any:
        return joblib.load(filepath)

    @staticmethod
    def save(obj_: Any, filepath: str) -> None:
        joblib.dump(obj_, filepath, compress=3)


def fix_seed(seed: int = 42):
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
    
def time_since(since: time.time, percent: float) -> str:
    def as_minutes(s):
        m = math.floor(s / 60)
        s -= m * 60
        return "%dm %ds" % (m, s)

    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return "%s (remain %s)" % (as_minutes(s), as_minutes(rs))

# %%
import numpy as np
# from PIL import Image


def load_npz(path: str) -> np.array:
    x = np.load(path)["arr_0"]
    # print(f"{os.path.basename(path)}: {x.shape}")
    return x


# def numpy_to_pil(arr: np.array):
#     return Image.fromarray(np.uint8(arr))

# %%
from sklearn.model_selection import (
    GroupKFold,
    KFold,
    StratifiedKFold,
    TimeSeriesSplit,
)


def generate_kf(cfg: ModelConfig) -> Generator:
    if cfg.kfold.method == "kf":
        kf = KFold(
            n_splits=cfg.kfold.number,
            shuffle=cfg.kfold.shuffle,
            random_state=cfg.basic.seed,
        )
    elif cfg.kfold.method == "skf":
        kf = StratifiedKFold(
            n_splits=cfg.kfold.number,
            shuffle=cfg.kfold.shuffle,
            random_state=cfg.basic.seed,
        )
    elif cfg.kfold.method == "gkf":
        kf = GroupKFold(n_splits=cfg.kfold.number)
    elif cfg.kfold.method == "sgkf":
        kf = StratifiedGroupKFold(
            n_splits=cfg.kfold.number, random_state=cfg.basic.seed
        )
    elif cfg.kfold.method == "tskf":
        kf = TimeSeriesSplit(n_splits=cfg.kfold.number)
    else:
        raise ValueError(f"{cfg.kfold.method} is not supported")
    return kf

# %%
import pandas as pd
from PIL import Image
from torch.utils import data
from torchvision import transforms as T


IMG_MEAN = [0.485, 0.456, 0.406]
IMG_STD = [0.229, 0.224, 0.225]


class ProbSpaceDataset(data.Dataset):
    def __init__(self, images: np.array, labels: Optional[np.array] = None, is_train: bool = True) -> None:
        """images.shape: (b, h, w, c), labels: (b,)"""
        assert (is_train and labels is not None) or (not is_train and labels is None)        
        self.is_train = is_train
        self.images = images
        self.labels = labels
        
        size = (ModelConfig.params.image_size, ModelConfig.params.image_size)
        additional_items = (
            [
                T.ToPILImage(),
                T.Resize(size),
            ]
            if not is_train
            else [
                T.ToPILImage(),
                T.RandomGrayscale(p=0.2),
                T.RandomHorizontalFlip(),
                T.ColorJitter(
                    brightness=0.3,
                    contrast=0.5,
                    saturation=[0.8, 1.3],
                    hue=[-0.05, 0.05],
                ),
                T.RandomResizedCrop(size),
            ]
        )
        self.transformer = T.Compose(
            [*additional_items, T.ToTensor(), T.Normalize(mean=IMG_MEAN, std=IMG_STD)]
        )

    def __getitem__(self, index) -> Dict[str, Any]:
        image = self.images[index]
        image = self.transformer(image)
        if self.is_train:
            label = self.labels[index]
        else:
            label = -1
        return {"image": image, "label": label}

    def __len__(self) -> int:
        return len(self.images)

# %%
import os
import sys

import timm
import torch
from torch import nn


class ProbSpaceModel(nn.Module):
    def __init__(self, model_config: ModelConfig):
        super().__init__()
        self.backbone = timm.create_model(model_config.params.model_name, pretrained=model_config.params.pretrained)
        self.in_features = self.backbone.fc.in_features
        self.backbone.fc = nn.Linear(self.in_features, model_config.params.target_size)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.softmax(x)
        return x


def build_model(model_config: ModelConfig):
    model = ProbSpaceModel(model_config)
    model.to(model_config.basic.device)
    return model


# def freeze_backbone_params(model):
#     # linear layer 以外を freeze
#     for param in model.parameters():
#         param.requires_grad = True
#     for param in model.backbone.parameters():
#         param.requires_grad = False
#     for param in model.softmax.parameters():
#         param.requires_grad = False

# %%
import datetime
import time
from collections import OrderedDict
from logging import Logger
from typing import Dict, Union

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch import optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from torchvision import models
from tqdm import tqdm


class BaseRunner:
    def __init__(self, cfg: ModelConfig):
        self.cfg = cfg
        self.params = cfg.params

    def _get_scheduler(
        self, optimizer: Union[optim.Adam]
    ) -> Union[
        lr_scheduler.ReduceLROnPlateau,
    ]:
        if self.params.scheduler.name == "ReduceLROnPlateau":
            scheduler = lr_scheduler.ReduceLROnPlateau(
                optimizer,
                mode=self.params.scheduler.mode,
                factor=self.params.scheduler.factor,
                patience=self.params.scheduler.patience,
                verbose=self.params.scheduler.verbose,
                eps=self.params.scheduler.eps,
            )
        else:
            raise ValueError(f"{self.params.scheduler.name} is not supported")
        return scheduler

    def _step_scheduler(
        self,
        scheduler: Union[
            lr_scheduler.ReduceLROnPlateau,
        ],
        avg_val_loss,
    ) -> Union[
        lr_scheduler.ReduceLROnPlateau,
    ]:
        if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        else:
            raise ValueError(f"{self.params.shceduler.name} is not supported")
        return scheduler

    def _evaluate(self, y_true: np.array, y_pred: np.array, verbose: bool = False) -> float:
        score = metrics.accuracy_score(y_true, y_pred)
        if verbose:
            print(f"Score: {score:<.5f}")
        return score


class TrainRunner(BaseRunner):
    def _train_epoch(self, train_loader, model, criterion, optimizer, scheduler, epoch):
        losses = AverageMeter()
        model.train()
        for _ in range(self.cfg.params.num_aug):
            for step, image_label_dict in enumerate(train_loader):
                images = image_label_dict.get("image").to(self.cfg.basic.device)
                labels = image_label_dict.get("label").to(self.cfg.basic.device)
                batch_size = labels.size(0)

                y_preds = model(images)
                loss = criterion(y_preds, labels)
                losses.update(loss.item(), batch_size)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        return losses.avg

    def _valid_epoch(self, valid_loader, model, criterion):
        losses = AverageMeter()
        model.eval()
        preds = []
        for _, image_label_dict in enumerate(valid_loader):
            images = image_label_dict.get("image").to(self.cfg.basic.device)
            labels = image_label_dict.get("label").to(self.cfg.basic.device)
            batch_size = labels.size(0)

            with torch.no_grad():
                y_preds = model(images)
            loss = criterion(y_preds, labels)
            losses.update(loss.item(), batch_size)
            preds.append(y_preds.to("cpu").numpy())
        predictions = np.concatenate(preds).reshape(-1, self.params.target_size)
        return losses.avg, predictions

    def _train(self, train: pd.DataFrame, n_fold: int) -> pd.DataFrame:
        print(f"fold: {n_fold}")
        train_images = load_npz(InputPath.train_images)
        train_labels = load_npz(InputPath.train_labels)        
        
        is_tta_mode = self.params.num_tta > 0
        num_times_tta = 1 if not is_tta_mode else self.params.num_tta

        trn_idx = train[train["fold"] != n_fold].index.tolist()
        val_idx = train[train["fold"] == n_fold].index.tolist()
        train_images_folds = train_images[trn_idx]
        valid_images_folds = train_images[val_idx]
        train_labels_folds = train_labels[trn_idx]
        valid_labels_folds = train_labels[val_idx]
        train_folds = train.loc[trn_idx].reset_index(drop=True)
        valid_folds = train.loc[val_idx].reset_index(drop=True)
        train_dataset = ProbSpaceDataset(
            train_images_folds,
            train_labels_folds,
            is_train=True,
#             transform=get_transforms(self.params, data="train"),
        )
        valid_dataset = ProbSpaceDataset(
            valid_images_folds,
            valid_labels_folds,
            is_train=is_tta_mode,
#             transform=get_transforms(self.params, data="valid"),
        )
        train_loader = DataLoader(
            train_dataset,
            batch_size=self.params.batch_size,
            shuffle=True,
            num_workers=self.params.num_workers,
            pin_memory=True,
            drop_last=True,
        )
        valid_loader = DataLoader(
            valid_dataset,
            batch_size=self.params.batch_size,
            shuffle=False,
            num_workers=self.params.num_workers,
            pin_memory=True,
            drop_last=False,
        )

        model = build_model(model_config=self.cfg)
        model.to(self.cfg.basic.device)
#         freeze_backbone_params(model)
        optimizer = optim.Adam(
            model.parameters(),
            lr=self.params.optimizer.lr,
            weight_decay=self.params.optimizer.weight_decay,
            amsgrad=self.params.optimizer.amsgrad,
        )
        scheduler = self._get_scheduler(optimizer)
        criterion = nn.CrossEntropyLoss()
        
        best_model = None
        best_score = 0
        scores: List[float] = []
        num_not_improved = 0
        for epoch in range(self.params.epochs):
            start_time = time.time()

            avg_loss = self._train_epoch(
                train_loader, model, criterion, optimizer, scheduler, epoch
            )
            avg_val_loss_list: List[float] = []
            preds_array = np.zeros((num_times_tta, len(val_idx), self.params.target_size))
            for i in range(num_times_tta):
                avg_val_loss, preds = self._valid_epoch(valid_loader, model, criterion)
                avg_val_loss_list.append(avg_val_loss)
                preds_array[i] = preds
            avg_val_loss = np.mean(avg_val_loss_list)
            scheduler = self._step_scheduler(scheduler, avg_val_loss)

            preds = preds_array.mean(axis=0)
            preds_ = np.argmax(preds, axis=1)
            valid_labels = valid_folds["target"].values
            score = self._evaluate(valid_labels, preds_)
            scores.append(score)
            elapsed = time.time() - start_time
            print(
                f"Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s"
            )
            print(f"Epoch {epoch+1} - Accuracy: {score}")
            if score > best_score:
                best_model = model
                best_score = score
                num_not_improved = 0
            else:
                num_not_improved += 1
            print(
                f"Epoch {epoch+1} - Best Score: {best_score:.4f}"
            )
            if self.params.early_stopping_rounds > 0 and self.params.early_stopping_rounds == num_not_improved:
                print(f"Early stopping break: not improved {num_not_improved} times in a row")
                break

        torch.save(
            {
                "model": best_model.state_dict(), 
                "preds": preds, 
                "best_score": best_score, 
                "scores": scores
            },
            f"{OutputPath.model}/{self.cfg.basic.run_name}_{n_fold}.pth",
        )
        check_point: Dict[str, Union[OrderedDict, torch.Tensor]] = torch.load(
            f"{OutputPath.model}/{self.cfg.basic.run_name}_{n_fold}.pth"
        )
        valid_folds["preds"] = np.argmax(check_point["preds"], axis=1)
        return valid_folds

    def run_cv(self, train: pd.DataFrame) -> None:
        print(f"debug mode: {self.cfg.basic.is_debug}")
        print(f"start time: {datetime.datetime.now()}")
        oof_df = pd.DataFrame()
        for n_fold in range(self.cfg.kfold.number):
            _oof_df = self._train(train, n_fold)
            print(f"========== fold: {n_fold} result ==========")
            self._evaluate(_oof_df["target"], _oof_df["preds"], verbose=True)
            oof_df = pd.concat([oof_df, _oof_df])
        print("========== CV ==========")
        self._evaluate(oof_df["target"], oof_df["preds"], verbose=True)
        Jbl.save(oof_df, f"{OutputPath.model}/oof_df_{self.cfg.basic.run_name}.jbl")

# %%
class InferenceRunner(BaseRunner):
    def _test_epoch(self, test_loader, model):
        model.eval()
        preds = []
        for step, image_label_dict in enumerate(test_loader):
            images = image_label_dict.get("image").to(self.cfg.basic.device)
            with torch.no_grad():
                y_preds = model(images)
            preds.append(y_preds.to("cpu").numpy())
        predictions = np.concatenate(preds).reshape(-1, self.params.target_size)
        return predictions

    def _test(self, test: pd.DataFrame, n_fold: int):
        print(f"fold: {n_fold}")
        test_images = load_npz(input_path.test_images)
        
        test_dataset = ProbSpaceDataset(
            test_images,
            is_train=False,
        )
        test_loader = DataLoader(
            test_dataset,
            batch_size=self.params.test_batch_size,
            shuffle=False,
            num_workers=self.params.num_workers,
            pin_memory=True,
            drop_last=False,
        )

        model = build_model(model_config=self.cfg)
        model_state = torch.load(f"{OutputPath.model}/{self.cfg.basic.run_name}_{n_fold}.pth")["model"]
        model.load_state_dict(model_state)
        model.to(self.cfg.basic.device)
        preds = self._test_epoch(test_loader, model)
        return preds
    
    def _submit(self, preds: np.array) -> None:
        test_images = load_npz(input_path.test_images)
        df_sub = pd.DataFrame({"id": list(range(len(test_images)))})
        df_sub = df_sub.assign(y=preds)
        print(df_sub.head())
        df_sub = df_sub.astype(int)
        path = f"{OutputPath.submission}/submission_{self.cfg.basic.run_name}.csv"
        df_sub.to_csv(path, index=False)
        print("submission.csv created")

    def run_cv(self, test: pd.DataFrame = None) -> None:
        oof_df = pd.DataFrame()
        preds: List[np.array] = []
        for n_fold in range(self.cfg.kfold.number):
            preds_fold = self._test(test, n_fold)
            preds.append(preds_fold)
        Jbl.save(preds, f"{OutputPath.model}/preds_test_{self.cfg.basic.run_name}.jbl")
        
        preds_mean = np.mean(preds, axis=0)
        assert preds_mean.shape == (497, 13)
        preds_mean = preds_mean.argmax(axis=1)
        assert preds_mean.shape == (497,)
        self._submit(preds_mean)

# %%
fix_seed()
input_path = InputPath()
model_config = ModelConfig()

# %%
train_labels = load_npz(InputPath.train_labels)

train = pd.DataFrame({"target": train_labels})

# %%
kf = generate_kf(model_config)
if model_config.kfold.method.endswith("gkf"):
    kf_generator = kf.split(
        train,
        train[self.fe_cfg.column.target],
        groups=train[self.kfold.columns],
    )
else:
    kf_generator = kf.split(train, train["target"])
for fold_i, (tr_idx, val_idx) in enumerate(kf_generator):
    print(
        f"fold: {fold_i} - {tr_idx[:5]}~{tr_idx[-5:]} ({len(tr_idx)})\t{val_idx[:5]}~{val_idx[-5:]} ({len(val_idx)})"
    )
    train.loc[val_idx, "fold"] = fold_i
train = train.assign(fold = train["fold"].astype(int))
# if model_config.kfold.method == "skf":
#     pd.set_option("display.max_rows", 65)
#     display(train.groupby(["fold", "target"]).size().to_frame())
# Out:
# fold: 0 - [1 2 3 6 7]~[645 646 648 651 653] (523)	[ 0  4  5 11 17]~[644 647 649 650 652] (131)
# fold: 1 - [0 1 2 4 5]~[649 650 651 652 653] (523)	[ 3  6  8  9 12]~[636 638 641 645 648] (131)
# fold: 2 - [0 1 3 4 5]~[649 650 651 652 653] (523)	[ 2 13 14 18 21]~[629 631 632 633 646] (131)
# fold: 3 - [0 2 3 4 5]~[648 649 650 651 652] (523)	[ 1 10 15 16 27]~[611 614 628 639 653] (131)
# fold: 4 - [0 1 2 3 4]~[648 649 650 652 653] (524)	[ 7 22 23 24 25]~[622 635 637 643 651] (130)

# %%
# %%time
TrainRunner(model_config).run_cv(train)
# Out:
# debug mode: False
# start time: 2021-08-05 22:17:37.945738
# fold: 0
# Epoch 1 - avg_train_loss: 2.5661  avg_val_loss: 2.5642  time: 19s
# Epoch 1 - Accuracy: 0.06870229007633588
# Epoch 1 - Best Score: 0.0687
# Epoch 2 - avg_train_loss: 2.5481  avg_val_loss: 2.5429  time: 19s
# Epoch 2 - Accuracy: 0.16030534351145037
# Epoch 2 - Best Score: 0.1603
# Epoch 3 - avg_train_loss: 2.5069  avg_val_loss: 2.5065  time: 19s
# Epoch 3 - Accuracy: 0.183206106870229
# Epoch 3 - Best Score: 0.1832
# Epoch 4 - avg_train_loss: 2.4502  avg_val_loss: 2.4802  time: 19s
# Epoch 4 - Accuracy: 0.22900763358778625
# Epoch 4 - Best Score: 0.2290
# Epoch 5 - avg_train_loss: 2.4079  avg_val_loss: 2.4557  time: 19s
# Epoch 5 - Accuracy: 0.25190839694656486
# Epoch 5 - Best Score: 0.2519
# Epoch 6 - avg_train_loss: 2.3719  avg_val_loss: 2.4389  time: 19s
# Epoch 6 - Accuracy: 0.2900763358778626
# Epoch 6 - Best Score: 0.2901
# Epoch 7 - avg_train_loss: 2.3350  avg_val_loss: 2.4222  time: 19s
# Epoch 7 - Accuracy: 0.2900763358778626
# Epoch 7 - Best Score: 0.2901
# Epoch 8 - avg_train_loss: 2.3079  avg_val_loss: 2.3977  time: 19s
# Epoch 8 - Accuracy: 0.29770992366412213
# Epoch 8 - Best Score: 0.2977
# Epoch 9 - avg_train_loss: 2.2909  avg_val_loss: 2.3788  time: 19s
# Epoch 9 - Accuracy: 0.3893129770992366
# Epoch 9 - Best Score: 0.3893
# Epoch 10 - avg_train_loss: 2.2559  avg_val_loss: 2.3575  time: 19s
# Epoch 10 - Accuracy: 0.366412213740458
# Epoch 10 - Best Score: 0.3893
# Epoch 11 - avg_train_loss: 2.2369  avg_val_loss: 2.3638  time: 19s
# Epoch 11 - Accuracy: 0.37404580152671757
# Epoch 11 - Best Score: 0.3893
# Epoch 12 - avg_train_loss: 2.2159  avg_val_loss: 2.3562  time: 19s
# Epoch 12 - Accuracy: 0.3893129770992366
# Epoch 12 - Best Score: 0.3893
# Epoch 13 - avg_train_loss: 2.1861  avg_val_loss: 2.3427  time: 19s
# Epoch 13 - Accuracy: 0.3816793893129771
# Epoch 13 - Best Score: 0.3893
# Epoch 14 - avg_train_loss: 2.1693  avg_val_loss: 2.3145  time: 19s
# Epoch 14 - Accuracy: 0.40458015267175573
# Epoch 14 - Best Score: 0.4046
# Epoch 15 - avg_train_loss: 2.1389  avg_val_loss: 2.3331  time: 19s
# Epoch 15 - Accuracy: 0.4122137404580153
# Epoch 15 - Best Score: 0.4122
# Epoch 16 - avg_train_loss: 2.1100  avg_val_loss: 2.3086  time: 19s
# Epoch 16 - Accuracy: 0.45038167938931295
# Epoch 16 - Best Score: 0.4504
# Epoch 17 - avg_train_loss: 2.0969  avg_val_loss: 2.2832  time: 19s
# Epoch 17 - Accuracy: 0.4580152671755725
# Epoch 17 - Best Score: 0.4580
# Epoch 18 - avg_train_loss: 2.0729  avg_val_loss: 2.3063  time: 19s
# Epoch 18 - Accuracy: 0.4580152671755725
# Epoch 18 - Best Score: 0.4580
# Epoch 19 - avg_train_loss: 2.0611  avg_val_loss: 2.2909  time: 19s
# Epoch 19 - Accuracy: 0.48091603053435117
# Epoch 19 - Best Score: 0.4809
# Epoch 20 - avg_train_loss: 2.0397  avg_val_loss: 2.2965  time: 19s
# Epoch 20 - Accuracy: 0.45038167938931295
# Epoch 20 - Best Score: 0.4809
# Epoch 21 - avg_train_loss: 2.0307  avg_val_loss: 2.3005  time: 19s
# Epoch 21 - Accuracy: 0.4351145038167939
# Epoch 21 - Best Score: 0.4809
# Epoch 22 - avg_train_loss: 2.0087  avg_val_loss: 2.3194  time: 19s
# Epoch 22 - Accuracy: 0.4122137404580153
# Epoch 22 - Best Score: 0.4809
# Epoch    23: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 23 - avg_train_loss: 1.9944  avg_val_loss: 2.2841  time: 19s
# Epoch 23 - Accuracy: 0.4580152671755725
# Epoch 23 - Best Score: 0.4809
# Epoch 24 - avg_train_loss: 1.9849  avg_val_loss: 2.2781  time: 19s
# Epoch 24 - Accuracy: 0.4961832061068702
# Epoch 24 - Best Score: 0.4962
# Epoch 25 - avg_train_loss: 1.9815  avg_val_loss: 2.2742  time: 19s
# Epoch 25 - Accuracy: 0.5038167938931297
# Epoch 25 - Best Score: 0.5038
# Epoch 26 - avg_train_loss: 1.9837  avg_val_loss: 2.2729  time: 19s
# Epoch 26 - Accuracy: 0.4961832061068702
# Epoch 26 - Best Score: 0.5038
# Epoch 27 - avg_train_loss: 1.9857  avg_val_loss: 2.2653  time: 19s
# Epoch 27 - Accuracy: 0.5267175572519084
# Epoch 27 - Best Score: 0.5267
# Epoch 28 - avg_train_loss: 1.9758  avg_val_loss: 2.2871  time: 19s
# Epoch 28 - Accuracy: 0.4351145038167939
# Epoch 28 - Best Score: 0.5267
# Epoch 29 - avg_train_loss: 1.9835  avg_val_loss: 2.2737  time: 19s
# Epoch 29 - Accuracy: 0.46564885496183206
# Epoch 29 - Best Score: 0.5267
# Epoch 30 - avg_train_loss: 1.9776  avg_val_loss: 2.2787  time: 19s
# Epoch 30 - Accuracy: 0.48091603053435117
# Epoch 30 - Best Score: 0.5267
# Epoch 31 - avg_train_loss: 1.9756  avg_val_loss: 2.2557  time: 19s
# Epoch 31 - Accuracy: 0.48854961832061067
# Epoch 31 - Best Score: 0.5267
# Epoch 32 - avg_train_loss: 1.9796  avg_val_loss: 2.2843  time: 19s
# Epoch 32 - Accuracy: 0.45038167938931295
# Epoch 32 - Best Score: 0.5267
# Epoch 33 - avg_train_loss: 1.9748  avg_val_loss: 2.2927  time: 19s
# Epoch 33 - Accuracy: 0.4351145038167939
# Epoch 33 - Best Score: 0.5267
# Epoch 34 - avg_train_loss: 1.9675  avg_val_loss: 2.2739  time: 19s
# Epoch 34 - Accuracy: 0.5038167938931297
# Epoch 34 - Best Score: 0.5267
# Epoch 35 - avg_train_loss: 1.9770  avg_val_loss: 2.2808  time: 19s
# Epoch 35 - Accuracy: 0.48854961832061067
# Epoch 35 - Best Score: 0.5267
# Epoch 36 - avg_train_loss: 1.9729  avg_val_loss: 2.2644  time: 19s
# Epoch 36 - Accuracy: 0.5190839694656488
# Epoch 36 - Best Score: 0.5267
# Epoch    37: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 37 - avg_train_loss: 1.9693  avg_val_loss: 2.2780  time: 19s
# Epoch 37 - Accuracy: 0.4732824427480916
# Epoch 37 - Best Score: 0.5267
# Early stopping break: not improved 10 times in a row
# ========== fold: 0 result ==========
# Score: 0.47328
# fold: 1
# Epoch 1 - avg_train_loss: 2.5545  avg_val_loss: 2.5460  time: 19s
# Epoch 1 - Accuracy: 0.19083969465648856
# Epoch 1 - Best Score: 0.1908
# Epoch 2 - avg_train_loss: 2.5248  avg_val_loss: 2.5159  time: 19s
# Epoch 2 - Accuracy: 0.2748091603053435
# Epoch 2 - Best Score: 0.2748
# Epoch 3 - avg_train_loss: 2.4759  avg_val_loss: 2.4690  time: 19s
# Epoch 3 - Accuracy: 0.29770992366412213
# Epoch 3 - Best Score: 0.2977
# Epoch 4 - avg_train_loss: 2.4306  avg_val_loss: 2.4509  time: 19s
# Epoch 4 - Accuracy: 0.2824427480916031
# Epoch 4 - Best Score: 0.2977
# Epoch 5 - avg_train_loss: 2.4016  avg_val_loss: 2.4265  time: 19s
# Epoch 5 - Accuracy: 0.2824427480916031
# Epoch 5 - Best Score: 0.2977
# Epoch 6 - avg_train_loss: 2.3753  avg_val_loss: 2.4105  time: 19s
# Epoch 6 - Accuracy: 0.31297709923664124
# Epoch 6 - Best Score: 0.3130
# Epoch 7 - avg_train_loss: 2.3531  avg_val_loss: 2.4167  time: 19s
# Epoch 7 - Accuracy: 0.3282442748091603
# Epoch 7 - Best Score: 0.3282
# Epoch 8 - avg_train_loss: 2.3283  avg_val_loss: 2.3957  time: 19s
# Epoch 8 - Accuracy: 0.31297709923664124
# Epoch 8 - Best Score: 0.3282
# Epoch 9 - avg_train_loss: 2.3070  avg_val_loss: 2.3893  time: 19s
# Epoch 9 - Accuracy: 0.3511450381679389
# Epoch 9 - Best Score: 0.3511
# Epoch 10 - avg_train_loss: 2.2814  avg_val_loss: 2.3887  time: 19s
# Epoch 10 - Accuracy: 0.366412213740458
# Epoch 10 - Best Score: 0.3664
# Epoch 11 - avg_train_loss: 2.2562  avg_val_loss: 2.3843  time: 19s
# Epoch 11 - Accuracy: 0.366412213740458
# Epoch 11 - Best Score: 0.3664
# Epoch 12 - avg_train_loss: 2.2344  avg_val_loss: 2.3711  time: 19s
# Epoch 12 - Accuracy: 0.3893129770992366
# Epoch 12 - Best Score: 0.3893
# Epoch 13 - avg_train_loss: 2.2145  avg_val_loss: 2.3529  time: 19s
# Epoch 13 - Accuracy: 0.37404580152671757
# Epoch 13 - Best Score: 0.3893
# Epoch 14 - avg_train_loss: 2.1867  avg_val_loss: 2.3313  time: 19s
# Epoch 14 - Accuracy: 0.4198473282442748
# Epoch 14 - Best Score: 0.4198
# Epoch 15 - avg_train_loss: 2.1690  avg_val_loss: 2.3499  time: 19s
# Epoch 15 - Accuracy: 0.3969465648854962
# Epoch 15 - Best Score: 0.4198
# Epoch 16 - avg_train_loss: 2.1517  avg_val_loss: 2.3495  time: 19s
# Epoch 16 - Accuracy: 0.37404580152671757
# Epoch 16 - Best Score: 0.4198
# Epoch 17 - avg_train_loss: 2.1388  avg_val_loss: 2.3573  time: 19s
# Epoch 17 - Accuracy: 0.3511450381679389
# Epoch 17 - Best Score: 0.4198
# Epoch 18 - avg_train_loss: 2.1238  avg_val_loss: 2.3311  time: 19s
# Epoch 18 - Accuracy: 0.40458015267175573
# Epoch 18 - Best Score: 0.4198
# Epoch 19 - avg_train_loss: 2.1113  avg_val_loss: 2.3387  time: 19s
# Epoch 19 - Accuracy: 0.3969465648854962
# Epoch 19 - Best Score: 0.4198
# Epoch    20: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 20 - avg_train_loss: 2.1012  avg_val_loss: 2.3328  time: 19s
# Epoch 20 - Accuracy: 0.40458015267175573
# Epoch 20 - Best Score: 0.4198
# Epoch 21 - avg_train_loss: 2.0921  avg_val_loss: 2.3458  time: 19s
# Epoch 21 - Accuracy: 0.3816793893129771
# Epoch 21 - Best Score: 0.4198
# Epoch 22 - avg_train_loss: 2.0875  avg_val_loss: 2.3430  time: 19s
# Epoch 22 - Accuracy: 0.4122137404580153
# Epoch 22 - Best Score: 0.4198
# Epoch 23 - avg_train_loss: 2.0922  avg_val_loss: 2.3456  time: 19s
# Epoch 23 - Accuracy: 0.37404580152671757
# Epoch 23 - Best Score: 0.4198
# Epoch 24 - avg_train_loss: 2.0798  avg_val_loss: 2.3077  time: 19s
# Epoch 24 - Accuracy: 0.40458015267175573
# Epoch 24 - Best Score: 0.4198
# Early stopping break: not improved 10 times in a row
# ========== fold: 1 result ==========
# Score: 0.40458
# fold: 2
# Epoch 1 - avg_train_loss: 2.5601  avg_val_loss: 2.5531  time: 19s
# Epoch 1 - Accuracy: 0.09923664122137404
# Epoch 1 - Best Score: 0.0992
# Epoch 2 - avg_train_loss: 2.5404  avg_val_loss: 2.5380  time: 19s
# Epoch 2 - Accuracy: 0.16030534351145037
# Epoch 2 - Best Score: 0.1603
# Epoch 3 - avg_train_loss: 2.5105  avg_val_loss: 2.5138  time: 19s
# Epoch 3 - Accuracy: 0.20610687022900764
# Epoch 3 - Best Score: 0.2061
# Epoch 4 - avg_train_loss: 2.4598  avg_val_loss: 2.4761  time: 19s
# Epoch 4 - Accuracy: 0.2595419847328244
# Epoch 4 - Best Score: 0.2595
# Epoch 5 - avg_train_loss: 2.4095  avg_val_loss: 2.4382  time: 19s
# Epoch 5 - Accuracy: 0.29770992366412213
# Epoch 5 - Best Score: 0.2977
# Epoch 6 - avg_train_loss: 2.3661  avg_val_loss: 2.3919  time: 19s
# Epoch 6 - Accuracy: 0.33587786259541985
# Epoch 6 - Best Score: 0.3359
# Epoch 7 - avg_train_loss: 2.3306  avg_val_loss: 2.3933  time: 19s
# Epoch 7 - Accuracy: 0.37404580152671757
# Epoch 7 - Best Score: 0.3740
# Epoch 8 - avg_train_loss: 2.3041  avg_val_loss: 2.3678  time: 19s
# Epoch 8 - Accuracy: 0.366412213740458
# Epoch 8 - Best Score: 0.3740
# Epoch 9 - avg_train_loss: 2.2734  avg_val_loss: 2.3620  time: 19s
# Epoch 9 - Accuracy: 0.366412213740458
# Epoch 9 - Best Score: 0.3740
# Epoch 10 - avg_train_loss: 2.2504  avg_val_loss: 2.3335  time: 19s
# Epoch 10 - Accuracy: 0.40458015267175573
# Epoch 10 - Best Score: 0.4046
# Epoch 11 - avg_train_loss: 2.2371  avg_val_loss: 2.3366  time: 19s
# Epoch 11 - Accuracy: 0.366412213740458
# Epoch 11 - Best Score: 0.4046
# Epoch 12 - avg_train_loss: 2.2160  avg_val_loss: 2.3236  time: 19s
# Epoch 12 - Accuracy: 0.4351145038167939
# Epoch 12 - Best Score: 0.4351
# Epoch 13 - avg_train_loss: 2.1984  avg_val_loss: 2.3500  time: 19s
# Epoch 13 - Accuracy: 0.366412213740458
# Epoch 13 - Best Score: 0.4351
# Epoch 14 - avg_train_loss: 2.1790  avg_val_loss: 2.3136  time: 19s
# Epoch 14 - Accuracy: 0.42748091603053434
# Epoch 14 - Best Score: 0.4351
# Epoch 15 - avg_train_loss: 2.1672  avg_val_loss: 2.3164  time: 19s
# Epoch 15 - Accuracy: 0.4122137404580153
# Epoch 15 - Best Score: 0.4351
# Epoch 16 - avg_train_loss: 2.1561  avg_val_loss: 2.3212  time: 19s
# Epoch 16 - Accuracy: 0.42748091603053434
# Epoch 16 - Best Score: 0.4351
# Epoch 17 - avg_train_loss: 2.1408  avg_val_loss: 2.3060  time: 19s
# Epoch 17 - Accuracy: 0.4351145038167939
# Epoch 17 - Best Score: 0.4351
# Epoch 18 - avg_train_loss: 2.1295  avg_val_loss: 2.2929  time: 19s
# Epoch 18 - Accuracy: 0.40458015267175573
# Epoch 18 - Best Score: 0.4351
# Epoch 19 - avg_train_loss: 2.1229  avg_val_loss: 2.3148  time: 19s
# Epoch 19 - Accuracy: 0.42748091603053434
# Epoch 19 - Best Score: 0.4351
# Epoch 20 - avg_train_loss: 2.0999  avg_val_loss: 2.2899  time: 19s
# Epoch 20 - Accuracy: 0.4351145038167939
# Epoch 20 - Best Score: 0.4351
# Epoch 21 - avg_train_loss: 2.0904  avg_val_loss: 2.3034  time: 19s
# Epoch 21 - Accuracy: 0.40458015267175573
# Epoch 21 - Best Score: 0.4351
# Epoch 22 - avg_train_loss: 2.0731  avg_val_loss: 2.2621  time: 19s
# Epoch 22 - Accuracy: 0.46564885496183206
# Epoch 22 - Best Score: 0.4656
# Epoch 23 - avg_train_loss: 2.0574  avg_val_loss: 2.2724  time: 19s
# Epoch 23 - Accuracy: 0.4351145038167939
# Epoch 23 - Best Score: 0.4656
# Epoch 24 - avg_train_loss: 2.0509  avg_val_loss: 2.2981  time: 19s
# Epoch 24 - Accuracy: 0.44274809160305345
# Epoch 24 - Best Score: 0.4656
# Epoch 25 - avg_train_loss: 2.0312  avg_val_loss: 2.2723  time: 19s
# Epoch 25 - Accuracy: 0.46564885496183206
# Epoch 25 - Best Score: 0.4656
# Epoch 26 - avg_train_loss: 2.0267  avg_val_loss: 2.2765  time: 19s
# Epoch 26 - Accuracy: 0.45038167938931295
# Epoch 26 - Best Score: 0.4656
# Epoch 27 - avg_train_loss: 2.0108  avg_val_loss: 2.2594  time: 19s
# Epoch 27 - Accuracy: 0.48854961832061067
# Epoch 27 - Best Score: 0.4885
# Epoch 28 - avg_train_loss: 2.0127  avg_val_loss: 2.3002  time: 19s
# Epoch 28 - Accuracy: 0.3969465648854962
# Epoch 28 - Best Score: 0.4885
# Epoch 29 - avg_train_loss: 1.9921  avg_val_loss: 2.2605  time: 19s
# Epoch 29 - Accuracy: 0.4580152671755725
# Epoch 29 - Best Score: 0.4885
# Epoch 30 - avg_train_loss: 1.9916  avg_val_loss: 2.2583  time: 19s
# Epoch 30 - Accuracy: 0.4732824427480916
# Epoch 30 - Best Score: 0.4885
# Epoch 31 - avg_train_loss: 1.9799  avg_val_loss: 2.2484  time: 19s
# Epoch 31 - Accuracy: 0.4961832061068702
# Epoch 31 - Best Score: 0.4962
# Epoch 32 - avg_train_loss: 1.9719  avg_val_loss: 2.2492  time: 19s
# Epoch 32 - Accuracy: 0.4961832061068702
# Epoch 32 - Best Score: 0.4962
# Epoch 33 - avg_train_loss: 1.9537  avg_val_loss: 2.2438  time: 19s
# Epoch 33 - Accuracy: 0.5038167938931297
# Epoch 33 - Best Score: 0.5038
# Epoch 34 - avg_train_loss: 1.9485  avg_val_loss: 2.2635  time: 19s
# Epoch 34 - Accuracy: 0.4732824427480916
# Epoch 34 - Best Score: 0.5038
# Epoch 35 - avg_train_loss: 1.9368  avg_val_loss: 2.2553  time: 19s
# Epoch 35 - Accuracy: 0.4732824427480916
# Epoch 35 - Best Score: 0.5038
# Epoch 36 - avg_train_loss: 1.9209  avg_val_loss: 2.2282  time: 19s
# Epoch 36 - Accuracy: 0.5038167938931297
# Epoch 36 - Best Score: 0.5038
# Epoch 37 - avg_train_loss: 1.9197  avg_val_loss: 2.2447  time: 19s
# Epoch 37 - Accuracy: 0.46564885496183206
# Epoch 37 - Best Score: 0.5038
# Epoch 38 - avg_train_loss: 1.9058  avg_val_loss: 2.2643  time: 19s
# Epoch 38 - Accuracy: 0.46564885496183206
# Epoch 38 - Best Score: 0.5038
# Epoch 39 - avg_train_loss: 1.8933  avg_val_loss: 2.2400  time: 19s
# Epoch 39 - Accuracy: 0.5038167938931297
# Epoch 39 - Best Score: 0.5038
# Epoch 40 - avg_train_loss: 1.8889  avg_val_loss: 2.2349  time: 19s
# Epoch 40 - Accuracy: 0.5267175572519084
# Epoch 40 - Best Score: 0.5267
# Epoch 41 - avg_train_loss: 1.8749  avg_val_loss: 2.2275  time: 19s
# Epoch 41 - Accuracy: 0.5190839694656488
# Epoch 41 - Best Score: 0.5267
# Epoch 42 - avg_train_loss: 1.8689  avg_val_loss: 2.2283  time: 19s
# Epoch 42 - Accuracy: 0.4961832061068702
# Epoch 42 - Best Score: 0.5267
# Epoch 43 - avg_train_loss: 1.8577  avg_val_loss: 2.2357  time: 19s
# Epoch 43 - Accuracy: 0.5038167938931297
# Epoch 43 - Best Score: 0.5267
# Epoch 44 - avg_train_loss: 1.8617  avg_val_loss: 2.2430  time: 19s
# Epoch 44 - Accuracy: 0.45038167938931295
# Epoch 44 - Best Score: 0.5267
# Epoch 45 - avg_train_loss: 1.8441  avg_val_loss: 2.2600  time: 19s
# Epoch 45 - Accuracy: 0.4961832061068702
# Epoch 45 - Best Score: 0.5267
# Epoch 46 - avg_train_loss: 1.8437  avg_val_loss: 2.2196  time: 19s
# Epoch 46 - Accuracy: 0.5114503816793893
# Epoch 46 - Best Score: 0.5267
# Epoch 47 - avg_train_loss: 1.8378  avg_val_loss: 2.2220  time: 19s
# Epoch 47 - Accuracy: 0.48854961832061067
# Epoch 47 - Best Score: 0.5267
# Epoch 48 - avg_train_loss: 1.8335  avg_val_loss: 2.2203  time: 19s
# Epoch 48 - Accuracy: 0.5419847328244275
# Epoch 48 - Best Score: 0.5420
# Epoch 49 - avg_train_loss: 1.8249  avg_val_loss: 2.2379  time: 19s
# Epoch 49 - Accuracy: 0.5190839694656488
# Epoch 49 - Best Score: 0.5420
# Epoch 50 - avg_train_loss: 1.8242  avg_val_loss: 2.2367  time: 19s
# Epoch 50 - Accuracy: 0.4961832061068702
# Epoch 50 - Best Score: 0.5420
# Epoch 51 - avg_train_loss: 1.8214  avg_val_loss: 2.2156  time: 19s
# Epoch 51 - Accuracy: 0.5343511450381679
# Epoch 51 - Best Score: 0.5420
# Epoch 52 - avg_train_loss: 1.8138  avg_val_loss: 2.2346  time: 19s
# Epoch 52 - Accuracy: 0.48854961832061067
# Epoch 52 - Best Score: 0.5420
# Epoch 53 - avg_train_loss: 1.8107  avg_val_loss: 2.2045  time: 19s
# Epoch 53 - Accuracy: 0.5114503816793893
# Epoch 53 - Best Score: 0.5420
# Epoch 54 - avg_train_loss: 1.8031  avg_val_loss: 2.2267  time: 19s
# Epoch 54 - Accuracy: 0.5419847328244275
# Epoch 54 - Best Score: 0.5420
# Epoch 55 - avg_train_loss: 1.8057  avg_val_loss: 2.2301  time: 19s
# Epoch 55 - Accuracy: 0.5114503816793893
# Epoch 55 - Best Score: 0.5420
# Epoch 56 - avg_train_loss: 1.7996  avg_val_loss: 2.2231  time: 19s
# Epoch 56 - Accuracy: 0.5038167938931297
# Epoch 56 - Best Score: 0.5420
# Epoch 57 - avg_train_loss: 1.8030  avg_val_loss: 2.2427  time: 19s
# Epoch 57 - Accuracy: 0.48854961832061067
# Epoch 57 - Best Score: 0.5420
# Epoch 58 - avg_train_loss: 1.7923  avg_val_loss: 2.2158  time: 19s
# Epoch 58 - Accuracy: 0.5343511450381679
# Epoch 58 - Best Score: 0.5420
# Early stopping break: not improved 10 times in a row
# ========== fold: 2 result ==========
# Score: 0.53435
# fold: 3
# Epoch 1 - avg_train_loss: 2.5561  avg_val_loss: 2.5493  time: 19s
# Epoch 1 - Accuracy: 0.1450381679389313
# Epoch 1 - Best Score: 0.1450
# Epoch 2 - avg_train_loss: 2.5344  avg_val_loss: 2.5296  time: 19s
# Epoch 2 - Accuracy: 0.25190839694656486
# Epoch 2 - Best Score: 0.2519
# Epoch 3 - avg_train_loss: 2.4954  avg_val_loss: 2.4890  time: 19s
# Epoch 3 - Accuracy: 0.2824427480916031
# Epoch 3 - Best Score: 0.2824
# Epoch 4 - avg_train_loss: 2.4501  avg_val_loss: 2.4518  time: 19s
# Epoch 4 - Accuracy: 0.29770992366412213
# Epoch 4 - Best Score: 0.2977
# Epoch 5 - avg_train_loss: 2.4146  avg_val_loss: 2.4290  time: 19s
# Epoch 5 - Accuracy: 0.3053435114503817
# Epoch 5 - Best Score: 0.3053
# Epoch 6 - avg_train_loss: 2.3845  avg_val_loss: 2.4001  time: 19s
# Epoch 6 - Accuracy: 0.3282442748091603
# Epoch 6 - Best Score: 0.3282
# Epoch 7 - avg_train_loss: 2.3526  avg_val_loss: 2.3781  time: 19s
# Epoch 7 - Accuracy: 0.366412213740458
# Epoch 7 - Best Score: 0.3664
# Epoch 8 - avg_train_loss: 2.3259  avg_val_loss: 2.3872  time: 19s
# Epoch 8 - Accuracy: 0.3511450381679389
# Epoch 8 - Best Score: 0.3664
# Epoch 9 - avg_train_loss: 2.3076  avg_val_loss: 2.3798  time: 19s
# Epoch 9 - Accuracy: 0.3511450381679389
# Epoch 9 - Best Score: 0.3664
# Epoch 10 - avg_train_loss: 2.2862  avg_val_loss: 2.3512  time: 19s
# Epoch 10 - Accuracy: 0.366412213740458
# Epoch 10 - Best Score: 0.3664
# Epoch 11 - avg_train_loss: 2.2689  avg_val_loss: 2.3635  time: 19s
# Epoch 11 - Accuracy: 0.366412213740458
# Epoch 11 - Best Score: 0.3664
# Epoch 12 - avg_train_loss: 2.2392  avg_val_loss: 2.3542  time: 19s
# Epoch 12 - Accuracy: 0.3816793893129771
# Epoch 12 - Best Score: 0.3817
# Epoch 13 - avg_train_loss: 2.2234  avg_val_loss: 2.3546  time: 19s
# Epoch 13 - Accuracy: 0.40458015267175573
# Epoch 13 - Best Score: 0.4046
# Epoch 14 - avg_train_loss: 2.2020  avg_val_loss: 2.3532  time: 19s
# Epoch 14 - Accuracy: 0.3816793893129771
# Epoch 14 - Best Score: 0.4046
# Epoch 15 - avg_train_loss: 2.1842  avg_val_loss: 2.3413  time: 19s
# Epoch 15 - Accuracy: 0.3893129770992366
# Epoch 15 - Best Score: 0.4046
# Epoch 16 - avg_train_loss: 2.1589  avg_val_loss: 2.3183  time: 19s
# Epoch 16 - Accuracy: 0.4122137404580153
# Epoch 16 - Best Score: 0.4122
# Epoch 17 - avg_train_loss: 2.1483  avg_val_loss: 2.3255  time: 19s
# Epoch 17 - Accuracy: 0.40458015267175573
# Epoch 17 - Best Score: 0.4122
# Epoch 18 - avg_train_loss: 2.1317  avg_val_loss: 2.3275  time: 19s
# Epoch 18 - Accuracy: 0.4198473282442748
# Epoch 18 - Best Score: 0.4198
# Epoch 19 - avg_train_loss: 2.1101  avg_val_loss: 2.3488  time: 19s
# Epoch 19 - Accuracy: 0.3969465648854962
# Epoch 19 - Best Score: 0.4198
# Epoch 20 - avg_train_loss: 2.0852  avg_val_loss: 2.3115  time: 19s
# Epoch 20 - Accuracy: 0.4351145038167939
# Epoch 20 - Best Score: 0.4351
# Epoch 21 - avg_train_loss: 2.0828  avg_val_loss: 2.3124  time: 19s
# Epoch 21 - Accuracy: 0.40458015267175573
# Epoch 21 - Best Score: 0.4351
# Epoch 22 - avg_train_loss: 2.0629  avg_val_loss: 2.3273  time: 19s
# Epoch 22 - Accuracy: 0.3893129770992366
# Epoch 22 - Best Score: 0.4351
# Epoch 23 - avg_train_loss: 2.0448  avg_val_loss: 2.2889  time: 19s
# Epoch 23 - Accuracy: 0.45038167938931295
# Epoch 23 - Best Score: 0.4504
# Epoch 24 - avg_train_loss: 2.0337  avg_val_loss: 2.3128  time: 19s
# Epoch 24 - Accuracy: 0.4122137404580153
# Epoch 24 - Best Score: 0.4504
# Epoch 25 - avg_train_loss: 2.0198  avg_val_loss: 2.2999  time: 19s
# Epoch 25 - Accuracy: 0.4351145038167939
# Epoch 25 - Best Score: 0.4504
# Epoch 26 - avg_train_loss: 2.0021  avg_val_loss: 2.3023  time: 19s
# Epoch 26 - Accuracy: 0.40458015267175573
# Epoch 26 - Best Score: 0.4504
# Epoch 27 - avg_train_loss: 1.9792  avg_val_loss: 2.2864  time: 19s
# Epoch 27 - Accuracy: 0.45038167938931295
# Epoch 27 - Best Score: 0.4504
# Epoch 28 - avg_train_loss: 1.9666  avg_val_loss: 2.3120  time: 19s
# Epoch 28 - Accuracy: 0.4198473282442748
# Epoch 28 - Best Score: 0.4504
# Epoch 29 - avg_train_loss: 1.9588  avg_val_loss: 2.2564  time: 19s
# Epoch 29 - Accuracy: 0.4732824427480916
# Epoch 29 - Best Score: 0.4733
# Epoch 30 - avg_train_loss: 1.9541  avg_val_loss: 2.2558  time: 19s
# Epoch 30 - Accuracy: 0.48854961832061067
# Epoch 30 - Best Score: 0.4885
# Epoch 31 - avg_train_loss: 1.9350  avg_val_loss: 2.2589  time: 19s
# Epoch 31 - Accuracy: 0.48091603053435117
# Epoch 31 - Best Score: 0.4885
# Epoch 32 - avg_train_loss: 1.9265  avg_val_loss: 2.2545  time: 19s
# Epoch 32 - Accuracy: 0.4961832061068702
# Epoch 32 - Best Score: 0.4962
# Epoch 33 - avg_train_loss: 1.9201  avg_val_loss: 2.2644  time: 19s
# Epoch 33 - Accuracy: 0.4961832061068702
# Epoch 33 - Best Score: 0.4962
# Epoch 34 - avg_train_loss: 1.9093  avg_val_loss: 2.2519  time: 19s
# Epoch 34 - Accuracy: 0.5038167938931297
# Epoch 34 - Best Score: 0.5038
# Epoch 35 - avg_train_loss: 1.8924  avg_val_loss: 2.2549  time: 19s
# Epoch 35 - Accuracy: 0.48854961832061067
# Epoch 35 - Best Score: 0.5038
# Epoch 36 - avg_train_loss: 1.8902  avg_val_loss: 2.2493  time: 19s
# Epoch 36 - Accuracy: 0.5038167938931297
# Epoch 36 - Best Score: 0.5038
# Epoch 37 - avg_train_loss: 1.8770  avg_val_loss: 2.2456  time: 19s
# Epoch 37 - Accuracy: 0.5114503816793893
# Epoch 37 - Best Score: 0.5115
# Epoch 38 - avg_train_loss: 1.8726  avg_val_loss: 2.2665  time: 19s
# Epoch 38 - Accuracy: 0.48091603053435117
# Epoch 38 - Best Score: 0.5115
# Epoch 39 - avg_train_loss: 1.8616  avg_val_loss: 2.2731  time: 19s
# Epoch 39 - Accuracy: 0.4732824427480916
# Epoch 39 - Best Score: 0.5115
# Epoch 40 - avg_train_loss: 1.8557  avg_val_loss: 2.2781  time: 19s
# Epoch 40 - Accuracy: 0.44274809160305345
# Epoch 40 - Best Score: 0.5115
# Epoch 41 - avg_train_loss: 1.8474  avg_val_loss: 2.2348  time: 19s
# Epoch 41 - Accuracy: 0.5419847328244275
# Epoch 41 - Best Score: 0.5420
# Epoch 42 - avg_train_loss: 1.8489  avg_val_loss: 2.2470  time: 19s
# Epoch 42 - Accuracy: 0.4580152671755725
# Epoch 42 - Best Score: 0.5420
# Epoch 43 - avg_train_loss: 1.8411  avg_val_loss: 2.2490  time: 19s
# Epoch 43 - Accuracy: 0.5114503816793893
# Epoch 43 - Best Score: 0.5420
# Epoch 44 - avg_train_loss: 1.8382  avg_val_loss: 2.2317  time: 19s
# Epoch 44 - Accuracy: 0.5648854961832062
# Epoch 44 - Best Score: 0.5649
# Epoch 45 - avg_train_loss: 1.8298  avg_val_loss: 2.2256  time: 19s
# Epoch 45 - Accuracy: 0.549618320610687
# Epoch 45 - Best Score: 0.5649
# Epoch 46 - avg_train_loss: 1.8249  avg_val_loss: 2.2252  time: 19s
# Epoch 46 - Accuracy: 0.5190839694656488
# Epoch 46 - Best Score: 0.5649
# Epoch 47 - avg_train_loss: 1.8192  avg_val_loss: 2.2507  time: 19s
# Epoch 47 - Accuracy: 0.5267175572519084
# Epoch 47 - Best Score: 0.5649
# Epoch 48 - avg_train_loss: 1.8100  avg_val_loss: 2.2263  time: 19s
# Epoch 48 - Accuracy: 0.5267175572519084
# Epoch 48 - Best Score: 0.5649
# Epoch 49 - avg_train_loss: 1.8151  avg_val_loss: 2.2040  time: 19s
# Epoch 49 - Accuracy: 0.5572519083969466
# Epoch 49 - Best Score: 0.5649
# Epoch 50 - avg_train_loss: 1.8022  avg_val_loss: 2.2423  time: 19s
# Epoch 50 - Accuracy: 0.48091603053435117
# Epoch 50 - Best Score: 0.5649
# Epoch 51 - avg_train_loss: 1.8075  avg_val_loss: 2.2316  time: 19s
# Epoch 51 - Accuracy: 0.5038167938931297
# Epoch 51 - Best Score: 0.5649
# Epoch 52 - avg_train_loss: 1.8047  avg_val_loss: 2.2392  time: 19s
# Epoch 52 - Accuracy: 0.5190839694656488
# Epoch 52 - Best Score: 0.5649
# Epoch 53 - avg_train_loss: 1.7996  avg_val_loss: 2.2312  time: 19s
# Epoch 53 - Accuracy: 0.5114503816793893
# Epoch 53 - Best Score: 0.5649
# Epoch 54 - avg_train_loss: 1.8016  avg_val_loss: 2.2133  time: 19s
# Epoch 54 - Accuracy: 0.549618320610687
# Epoch 54 - Best Score: 0.5649
# Early stopping break: not improved 10 times in a row
# ========== fold: 3 result ==========
# Score: 0.54962
# fold: 4
# Epoch 1 - avg_train_loss: 2.5534  avg_val_loss: 2.5525  time: 19s
# Epoch 1 - Accuracy: 0.17692307692307693
# Epoch 1 - Best Score: 0.1769
# Epoch 2 - avg_train_loss: 2.5262  avg_val_loss: 2.5198  time: 19s
# Epoch 2 - Accuracy: 0.2692307692307692
# Epoch 2 - Best Score: 0.2692
# Epoch 3 - avg_train_loss: 2.4737  avg_val_loss: 2.4772  time: 19s
# Epoch 3 - Accuracy: 0.27692307692307694
# Epoch 3 - Best Score: 0.2769
# Epoch 4 - avg_train_loss: 2.4225  avg_val_loss: 2.4481  time: 19s
# Epoch 4 - Accuracy: 0.2923076923076923
# Epoch 4 - Best Score: 0.2923
# Epoch 5 - avg_train_loss: 2.3931  avg_val_loss: 2.4261  time: 19s
# Epoch 5 - Accuracy: 0.3153846153846154
# Epoch 5 - Best Score: 0.3154
# Epoch 6 - avg_train_loss: 2.3667  avg_val_loss: 2.4274  time: 19s
# Epoch 6 - Accuracy: 0.3
# Epoch 6 - Best Score: 0.3154
# Epoch 7 - avg_train_loss: 2.3416  avg_val_loss: 2.3997  time: 19s
# Epoch 7 - Accuracy: 0.34615384615384615
# Epoch 7 - Best Score: 0.3462
# Epoch 8 - avg_train_loss: 2.3238  avg_val_loss: 2.4088  time: 19s
# Epoch 8 - Accuracy: 0.3230769230769231
# Epoch 8 - Best Score: 0.3462
# Epoch 9 - avg_train_loss: 2.2992  avg_val_loss: 2.3876  time: 19s
# Epoch 9 - Accuracy: 0.35384615384615387
# Epoch 9 - Best Score: 0.3538
# Epoch 10 - avg_train_loss: 2.2660  avg_val_loss: 2.3739  time: 19s
# Epoch 10 - Accuracy: 0.4
# Epoch 10 - Best Score: 0.4000
# Epoch 11 - avg_train_loss: 2.2372  avg_val_loss: 2.3783  time: 19s
# Epoch 11 - Accuracy: 0.36923076923076925
# Epoch 11 - Best Score: 0.4000
# Epoch 12 - avg_train_loss: 2.2236  avg_val_loss: 2.3520  time: 19s
# Epoch 12 - Accuracy: 0.3923076923076923
# Epoch 12 - Best Score: 0.4000
# Epoch 13 - avg_train_loss: 2.2034  avg_val_loss: 2.3668  time: 19s
# Epoch 13 - Accuracy: 0.36153846153846153
# Epoch 13 - Best Score: 0.4000
# Epoch 14 - avg_train_loss: 2.1814  avg_val_loss: 2.3592  time: 19s
# Epoch 14 - Accuracy: 0.3923076923076923
# Epoch 14 - Best Score: 0.4000
# Epoch 15 - avg_train_loss: 2.1617  avg_val_loss: 2.3346  time: 19s
# Epoch 15 - Accuracy: 0.4076923076923077
# Epoch 15 - Best Score: 0.4077
# Epoch 16 - avg_train_loss: 2.1423  avg_val_loss: 2.3226  time: 19s
# Epoch 16 - Accuracy: 0.43846153846153846
# Epoch 16 - Best Score: 0.4385
# Epoch 17 - avg_train_loss: 2.1204  avg_val_loss: 2.2980  time: 19s
# Epoch 17 - Accuracy: 0.47692307692307695
# Epoch 17 - Best Score: 0.4769
# Epoch 18 - avg_train_loss: 2.1085  avg_val_loss: 2.3149  time: 19s
# Epoch 18 - Accuracy: 0.49230769230769234
# Epoch 18 - Best Score: 0.4923
# Epoch 19 - avg_train_loss: 2.1009  avg_val_loss: 2.3378  time: 19s
# Epoch 19 - Accuracy: 0.4076923076923077
# Epoch 19 - Best Score: 0.4923
# Epoch 20 - avg_train_loss: 2.0853  avg_val_loss: 2.3189  time: 19s
# Epoch 20 - Accuracy: 0.45384615384615384
# Epoch 20 - Best Score: 0.4923
# Epoch 21 - avg_train_loss: 2.0705  avg_val_loss: 2.2999  time: 19s
# Epoch 21 - Accuracy: 0.4461538461538462
# Epoch 21 - Best Score: 0.4923
# Epoch 22 - avg_train_loss: 2.0572  avg_val_loss: 2.3037  time: 19s
# Epoch 22 - Accuracy: 0.4461538461538462
# Epoch 22 - Best Score: 0.4923
# Epoch    23: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 23 - avg_train_loss: 2.0453  avg_val_loss: 2.3049  time: 19s
# Epoch 23 - Accuracy: 0.43846153846153846
# Epoch 23 - Best Score: 0.4923
# Epoch 24 - avg_train_loss: 2.0418  avg_val_loss: 2.2936  time: 19s
# Epoch 24 - Accuracy: 0.43846153846153846
# Epoch 24 - Best Score: 0.4923
# Epoch 25 - avg_train_loss: 2.0326  avg_val_loss: 2.2820  time: 19s
# Epoch 25 - Accuracy: 0.46923076923076923
# Epoch 25 - Best Score: 0.4923
# Epoch 26 - avg_train_loss: 2.0345  avg_val_loss: 2.3162  time: 19s
# Epoch 26 - Accuracy: 0.43846153846153846
# Epoch 26 - Best Score: 0.4923
# Epoch 27 - avg_train_loss: 2.0256  avg_val_loss: 2.3170  time: 19s
# Epoch 27 - Accuracy: 0.4461538461538462
# Epoch 27 - Best Score: 0.4923
# Epoch 28 - avg_train_loss: 2.0223  avg_val_loss: 2.2898  time: 19s
# Epoch 28 - Accuracy: 0.4461538461538462
# Epoch 28 - Best Score: 0.4923
# Early stopping break: not improved 10 times in a row
# ========== fold: 4 result ==========
# Score: 0.44615
# ========== CV ==========
# Score: 0.48165
# CPU times: user 6h 18min 5s, sys: 7min 23s, total: 6h 25min 29s
# Wall time: 1h 2min 35s

# %%
# _oof_df = Jbl.load(f"{OutputPath.model}/oof_df_{model_config.basic.run_name}.jbl")
# print("========== CV ==========")
# TrainRunner(model_config)._evaluate(_oof_df["target"], _oof_df["preds"], verbose=True)

Jbl.load(f"{OutputPath.model}/oof_df_{model_config.basic.run_name}.jbl")
# Out:
#      target  fold  preds
# 0         5     0     11
# 1         6     0      6
# 2         4     0      0
# 3         7     0      7
# 4         0     0      6
# ..      ...   ...    ...
# 125       3     4     11
# 126      11     4      0
# 127       5     4      2
# 128       9     4      9
# 129       2     4      2
#
# [654 rows x 3 columns]

# %%
sns.countplot(x=train_labels, label="true")
plt.show()
sns.countplot(x=Jbl.load(f"{OutputPath.model}/oof_df_{model_config.basic.run_name}.jbl")["preds"])
plt.show()

# %%
InferenceRunner(model_config).run_cv()
# Out:
# fold: 0
# fold: 1
# fold: 2
# fold: 3
# fold: 4
#    id  y
# 0   0  2
# 1   1  2
# 2   2  2
# 3   3  0
# 4   4  0
# submission.csv created
